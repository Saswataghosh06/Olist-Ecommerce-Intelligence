# %%
import pandas as pd
from databricks import sql
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Establish the Databricks Connection
connection = sql.connect(
    server_hostname="YOUR_SERVER_HOSTNAME",
    http_path="YOUR_HTTP_PATH",
    access_token="YOUR_DATABRICKS_TOKEN"
)

# 2. Query the Gold layer (Seller Performance Mart)
query = "SELECT * FROM olist_analytics.gold.mart_seller_performance"
df_sellers = pd.read_sql(query, connection)

# 3. Verify the data loaded
display(df_sellers.head())
